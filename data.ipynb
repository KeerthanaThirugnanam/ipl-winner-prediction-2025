# %%
import pandas as pd 
import numpy as np

# %%
data1=pd.read_csv("datasets/deliveries.csv")
data2=pd.read_csv("datasets/matches.csv")

# %%
data1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
data2.head()
# Out:
#    match_id   season        city        date match_type player_of_match  \
# 0    335982  2007/08   Bangalore  18/04/2008     League     BB McCullum
# 1    335983  2007/08  Chandigarh  19/04/2008     League      MEK Hussey
# 2    335984  2007/08       Delhi  19/04/2008     League     MF Maharoof
# 3    335985  2007/08      Mumbai  20/04/2008     League      MV Boucher
# 4    335986  2007/08     Kolkata  20/04/2008     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
total_run = data1.groupby(['match_id','inning']).sum()['total_runs'].add(1).reset_index()

# %%
total_run
# Out:
#       match_id  inning  total_runs
# 0       335982       1         223
# 1       335982       2          83
# 2       335983       1         241
# 3       335983       2         208
# 4       335984       1         130
# ...        ...     ...         ...
# 2212   1426310       2         175
# 2213   1426311       1         176
# 2214   1426311       2         140
# 2215   1426312       1         114
# 2216   1426312       2         115
#
# [2217 rows x 3 columns]

# %%
total_run = total_run[total_run['inning']==1]
total_run
# Out:
#       match_id  inning  total_runs
# 0       335982       1         223
# 2       335983       1         241
# 4       335984       1         130
# 6       335985       1         166
# 8       335986       1         111
# ...        ...     ...         ...
# 2207   1426307       1         215
# 2209   1426309       1         160
# 2211   1426310       1         173
# 2213   1426311       1         176
# 2215   1426312       1         114
#
# [1095 rows x 3 columns]

# %%
match_df = data2.merge(total_run[['match_id','total_runs']],left_on='match_id',right_on='match_id')
match_df
# Out:
#       match_id   season        city        date   match_type  player_of_match  \
# 0       335982  2007/08   Bangalore  18/04/2008       League      BB McCullum
# 1       335983  2007/08  Chandigarh  19/04/2008       League       MEK Hussey
# 2       335984  2007/08       Delhi  19/04/2008       League      MF Maharoof
# 3       335985  2007/08      Mumbai  20/04/2008       League       MV Boucher
# 4       335986  2007/08     Kolkata  20/04/2008       League        DJ Hussey
# ...        ...      ...         ...         ...          ...              ...
# 1090   1426307     2024   Hyderabad  19/05/2024       League  Abhishek Sharma
# 1091   1426309     2024   Ahmedabad  21/05/2024  Qualifier 1         MA Starc
# 1092   1426310     2024   Ahmedabad  22/05/2024   Eliminator         R Ashwin
# 1093   1426311     2024     Chennai  24/05/2024  Qualifier 2    Shahbaz Ahmed
# 1094   1426312     2024     Chennai  26/05/2024        Final         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner  ...                       winner   result  \
# 0     Royal Challengers Bangalore  ...        Kolkata Knight Riders     runs
# 1             Chennai Super Kings  ...          Chennai Super Kings     runs
# 2                Rajasthan Royals  ...             Delhi Daredevils  wickets
# 3                  Mumbai Indians  ...  Royal Challengers Bangalore  wickets
# 4                 Deccan Chargers  ...        Kolkata Knight Riders  wickets
# ...                           ...  ...                          ...      ...
# 1090                 Punjab Kings  ...          Sunrisers Hyderabad  wickets
# 1091          Sunrisers Hyderabad  ...        Kolkata Knight Riders  wickets
# 1092             Rajasthan Royals  ...             Rajasthan Royals  wickets
# 1093             Rajasthan Royals  ...          Sunrisers Hyderabad     runs
# 1094          Sunrisers Hyderabad  ...        Kolkata Knight Riders  wickets
#
#      result_margin  target_runs  target_overs  super_over method  \
# 0            140.0        223.0          20.0           N    NaN
# 1             33.0        241.0          20.0           N    NaN
# 2              9.0        130.0          20.0           N    NaN
# 3              5.0        166.0          20.0           N    NaN
# 4              5.0        111.0          20.0           N    NaN
# ...            ...          ...           ...         ...    ...
# 1090           4.0        215.0          20.0           N    NaN
# 1091           8.0        160.0          20.0           N    NaN
# 1092           4.0        173.0          20.0           N    NaN
# 1093          36.0        176.0          20.0           N    NaN
# 1094           8.0        114.0          20.0           N    NaN
#
#                     umpire1               umpire2 total_runs
# 0                 Asad Rauf           RE Koertzen        223
# 1                 MR Benson            SL Shastri        241
# 2                 Aleem Dar        GA Pratapkumar        130
# 3                  SJ Davis             DJ Harper        166
# 4                 BF Bowden           K Hariharan        111
# ...                     ...                   ...        ...
# 1090            Nitin Menon             VK Sharma        215
# 1091           AK Chaudhary              R Pandit        160
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar        173
# 1093            Nitin Menon             VK Sharma        176
# 1094          J Madanagopal           Nitin Menon        114
#
# [1095 rows x 21 columns]

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Name: count, dtype: int64

# %%
match_df['team1'] = match_df['team1'].replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['team1'] = match_df['team1'].replace('Kings XI Punjab','Punjab Kings')
match_df['team2'] = match_df['team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Delhi Capitals                 126
# Sunrisers Hyderabad            125
# Mumbai Indians                 123
# Punjab Kings                   123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Pune Warriors                   23
# Lucknow Super Giants            23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: count, dtype: int64

# %%
teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Punjab Kings', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    127
# Chennai Super Kings            124
# Delhi Capitals                 118
# Sunrisers Hyderabad            117
# Punjab Kings                   115
# Mumbai Indians                 113
# Kolkata Knight Riders          113
# Rajasthan Royals                97
# Lucknow Super Giants            22
# Gujarat Titans                  19
# Name: count, dtype: int64

# %%
match_df.shape
# Out:
# (965, 21)

# %%
match_df = match_df[['match_id','city','winner','total_runs', 'team1', 'team2']]

# %%
match_df.shape
# Out:
# (965, 6)

# %%
second_innings = match_df.merge(data1,on='match_id')
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  \
# 0         335982  Bangalore  Kolkata Knight Riders           223
# 1         335982  Bangalore  Kolkata Knight Riders           223
# 2         335982  Bangalore  Kolkata Knight Riders           223
# 3         335982  Bangalore  Kolkata Knight Riders           223
# 4         335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 0       Royal Challengers Bangalore  Kolkata Knight Riders       1
# 1       Royal Challengers Bangalore  Kolkata Knight Riders       1
# 2       Royal Challengers Bangalore  Kolkata Knight Riders       1
# 3       Royal Challengers Bangalore  Kolkata Knight Riders       1
# 4       Royal Challengers Bangalore  Kolkata Knight Riders       1
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                  batting_team                 bowling_team  over  ...  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore     0  ...
# 1       Kolkata Knight Riders  Royal Challengers Bangalore     0  ...
# 2       Kolkata Knight Riders  Royal Challengers Bangalore     0  ...
# 3       Kolkata Knight Riders  Royal Challengers Bangalore     0  ...
# 4       Kolkata Knight Riders  Royal Challengers Bangalore     0  ...
# ...                       ...                          ...   ...  ...
# 230277  Kolkata Knight Riders          Sunrisers Hyderabad     9  ...
# 230278  Kolkata Knight Riders          Sunrisers Hyderabad     9  ...
# 230279  Kolkata Knight Riders          Sunrisers Hyderabad    10  ...
# 230280  Kolkata Knight Riders          Sunrisers Hyderabad    10  ...
# 230281  Kolkata Knight Riders          Sunrisers Hyderabad    10  ...
#
#                bowler  non_striker batsman_runs extra_runs  total_runs_y  \
# 0             P Kumar  BB McCullum            0          1             1
# 1             P Kumar   SC Ganguly            0          0             0
# 2             P Kumar   SC Ganguly            0          1             1
# 3             P Kumar   SC Ganguly            0          0             0
# 4             P Kumar   SC Ganguly            0          0             0
# ...               ...          ...          ...        ...           ...
# 230277     AK Markram      VR Iyer            1          0             1
# 230278     AK Markram      SS Iyer            1          0             1
# 230279  Shahbaz Ahmed      SS Iyer            1          0             1
# 230280  Shahbaz Ahmed      VR Iyer            1          0             1
# 230281  Shahbaz Ahmed      SS Iyer            1          0             1
#
#         extras_type  is_wicket player_dismissed  dismissal_kind fielder
# 0           legbyes          0              NaN             NaN     NaN
# 1               NaN          0              NaN             NaN     NaN
# 2             wides          0              NaN             NaN     NaN
# 3               NaN          0              NaN             NaN     NaN
# 4               NaN          0              NaN             NaN     NaN
# ...             ...        ...              ...             ...     ...
# 230277          NaN          0              NaN             NaN     NaN
# 230278          NaN          0              NaN             NaN     NaN
# 230279          NaN          0              NaN             NaN     NaN
# 230280          NaN          0              NaN             NaN     NaN
# 230281          NaN          0              NaN             NaN     NaN
#
# [230282 rows x 22 columns]

# %%
second_innings = second_innings[second_innings['inning']==2]
second_innings.shape
# Out:
# (111082, 22)

# %%
second_innings['team1'] = second_innings['team1'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['team2'] = second_innings['team2'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['team1'] = second_innings['team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['team2'] = second_innings['team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['team1'] = second_innings['team1'].replace('Kings XI Punjab','Punjab Kings')
second_innings['team2'] = second_innings['team2'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team1'] = second_innings['team1'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team2'] = second_innings['team2'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team1'] = second_innings['team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team2'] = second_innings['team2'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team1'] = second_innings['team1'].replace('Kings XI Punjab','Punjab Kings')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3768637699.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['team2'] = second_innings['team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['team1'].value_counts()
# Out:
# team1
# Chennai Super Kings            14752
# Royal Challengers Bangalore    14289
# Sunrisers Hyderabad            13535
# Delhi Capitals                 13513
# Punjab Kings                   13229
# Mumbai Indians                 13162
# Kolkata Knight Riders          12771
# Rajasthan Royals               11186
# Lucknow Super Giants            2488
# Gujarat Titans                  2157
# Name: count, dtype: int64

# %%
second_innings.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'team1', 'team2',
#        'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter',
#        'bowler', 'non_striker', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder'],
#       dtype='object')

# %%
second_innings.shape
# Out:
# (111082, 22)

# %%
#function tp determine bowling team
def determine_bowling_team(row):
    if row['batting_team'] == row['team1']:
        return row['team2']
    else:
        return row['team1']

# Create the new 'BowlingTeam' column
second_innings['bowling_team'] = second_innings.apply(determine_bowling_team, axis=1)
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\569777432.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['bowling_team'] = second_innings.apply(determine_bowling_team, axis=1)

# %%
second_innings['batting_team'] = second_innings['batting_team'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['bowling_team'] = second_innings['bowling_team'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['batting_team'] = second_innings['batting_team'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['bowling_team'] = second_innings['bowling_team'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['batting_team'] = second_innings['batting_team'].replace('Kings XI Punjab','Punjab Kings')
second_innings['bowling_team'] = second_innings['bowling_team'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['batting_team'] = second_innings['batting_team'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['bowling_team'] = second_innings['bowling_team'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['batting_team'] = second_innings['batting_team'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['bowling_team'] = second_innings['bowling_team'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['batting_team'] = second_innings['batting_team'].replace('Kings XI Punjab','Punjab Kings')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1160698263.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['bowling_team'] = second_innings['bowling_team'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#                bowler non_striker batsman_runs extra_runs  total_runs_y  \
# 124          AB Dinda    W Jaffer            1          0             1
# 125          AB Dinda    R Dravid            0          1             1
# 126          AB Dinda    R Dravid            0          0             0
# 127          AB Dinda    R Dravid            1          0             1
# 128          AB Dinda    W Jaffer            1          0             1
# ...               ...         ...          ...        ...           ...
# 230277     AK Markram     VR Iyer            1          0             1
# 230278     AK Markram     SS Iyer            1          0             1
# 230279  Shahbaz Ahmed     SS Iyer            1          0             1
# 230280  Shahbaz Ahmed     VR Iyer            1          0             1
# 230281  Shahbaz Ahmed     SS Iyer            1          0             1
#
#         extras_type  is_wicket player_dismissed  dismissal_kind fielder
# 124             NaN          0              NaN             NaN     NaN
# 125           wides          0              NaN             NaN     NaN
# 126             NaN          0              NaN             NaN     NaN
# 127             NaN          0              NaN             NaN     NaN
# 128             NaN          0              NaN             NaN     NaN
# ...             ...        ...              ...             ...     ...
# 230277          NaN          0              NaN             NaN     NaN
# 230278          NaN          0              NaN             NaN     NaN
# 230279          NaN          0              NaN             NaN     NaN
# 230280          NaN          0              NaN             NaN     NaN
# 230281          NaN          0              NaN             NaN     NaN
#
# [111082 rows x 22 columns]

# %%
second_innings['bowling_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Lucknow Super Giants', 'Gujarat Titans'], dtype=object)

# %%
second_innings.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'team1', 'team2',
#        'inning', 'batting_team', 'bowling_team', 'over', 'ball', 'batter',
#        'bowler', 'non_striker', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder'],
#       dtype='object')

# %%
print(second_innings.dtypes)
# Out:
# match_id             int64
# city                object
# winner              object
# total_runs_x         int64
# team1               object
# team2               object
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batter              object
# bowler              object
# non_striker         object
# batsman_runs         int64
# extra_runs           int64
# total_runs_y         int64
# extras_type         object
# is_wicket            int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
second_innings['total_runs_y'] = pd.to_numeric(second_innings['total_runs_y'], errors='coerce')
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\773179244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['total_runs_y'] = pd.to_numeric(second_innings['total_runs_y'], errors='coerce')

# %%
second_innings['total_runs_y'].fillna(0, inplace=True)  # Replace NaNs with 0, or
# second_innings.dropna(subset=['total_runs_y'], inplace=True)  # Drop rows with NaNs in 'total_runs_y'
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\189899641.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   second_innings['total_runs_y'].fillna(0, inplace=True)
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\189899641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['total_runs_y'].fillna(0, inplace=True)

# %%
second_innings['current_Score'] = second_innings.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\2616048482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['current_Score'] = second_innings.groupby('match_id')['total_runs_y'].cumsum()

# %%
second_innings['runs_left'] = second_innings['total_runs_x'] - second_innings['current_Score']
second_innings
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3504902464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['runs_left'] = second_innings['total_runs_x'] - second_innings['current_Score']
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#         extra_runs total_runs_y extras_type is_wicket  player_dismissed  \
# 124              0            1         NaN         0               NaN
# 125              1            1       wides         0               NaN
# 126              0            0         NaN         0               NaN
# 127              0            1         NaN         0               NaN
# 128              0            1         NaN         0               NaN
# ...            ...          ...         ...       ...               ...
# 230277           0            1         NaN         0               NaN
# 230278           0            1         NaN         0               NaN
# 230279           0            1         NaN         0               NaN
# 230280           0            1         NaN         0               NaN
# 230281           0            1         NaN         0               NaN
#
#         dismissal_kind  fielder current_score  current_Score runs_left
# 124                NaN      NaN             1              1       222
# 125                NaN      NaN             2              2       221
# 126                NaN      NaN             2              2       221
# 127                NaN      NaN             3              3       220
# 128                NaN      NaN             4              4       219
# ...                ...      ...           ...            ...       ...
# 230277             NaN      NaN           110            110         4
# 230278             NaN      NaN           111            111         3
# 230279             NaN      NaN           112            112         2
# 230280             NaN      NaN           113            113         1
# 230281             NaN      NaN           114            114         0
#
# [111082 rows x 25 columns]

# %%
second_innings['balls_left'] = 126 - (second_innings['over']*6 +second_innings['ball'])
second_innings
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3450208605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['balls_left'] = 126 - (second_innings['over']*6 +second_innings['ball'])
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#         total_runs_y extras_type is_wicket player_dismissed  dismissal_kind  \
# 124                1         NaN         0              NaN             NaN
# 125                1       wides         0              NaN             NaN
# 126                0         NaN         0              NaN             NaN
# 127                1         NaN         0              NaN             NaN
# 128                1         NaN         0              NaN             NaN
# ...              ...         ...       ...              ...             ...
# 230277             1         NaN         0              NaN             NaN
# 230278             1         NaN         0              NaN             NaN
# 230279             1         NaN         0              NaN             NaN
# 230280             1         NaN         0              NaN             NaN
# 230281             1         NaN         0              NaN             NaN
#
#         fielder  current_score current_Score  runs_left balls_left
# 124         NaN              1             1        222        125
# 125         NaN              2             2        221        124
# 126         NaN              2             2        221        123
# 127         NaN              3             3        220        122
# 128         NaN              4             4        219        121
# ...         ...            ...           ...        ...        ...
# 230277      NaN            110           110          4         67
# 230278      NaN            111           111          3         66
# 230279      NaN            112           112          2         65
# 230280      NaN            113           113          1         64
# 230281      NaN            114           114          0         63
#
# [111082 rows x 26 columns]

# %%
# Select the columns of interest
columns_to_check = ['current_Score', 'runs_left', 'balls_left']

# Check how many values in each column are negative
negative_counts = second_innings[columns_to_check].lt(0).sum()

# Display the counts
print("Number of negative values in each column:")
print(negative_counts)
# Out:
# Number of negative values in each column:
# current_Score      0
# runs_left        303
# balls_left         0
# dtype: int64

# %%
second_innings['player_dismissed'] = second_innings['player_dismissed'].fillna("0")
second_innings['player_dismissed'] = second_innings['player_dismissed'].apply(lambda x:x if x=="0" else "1")
second_innings['player_dismissed'] = second_innings['player_dismissed'].astype('int')
wickets = second_innings.groupby('match_id')['player_dismissed'].cumsum()
second_innings['wickets_remaining'] = 10-wickets
second_innings
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\2397989033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_dismissed'] = second_innings['player_dismissed'].fillna("0")
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\2397989033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_dismissed'] = second_innings['player_dismissed'].apply(lambda x:x if x=="0" else "1")
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\2397989033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_dismissed'] = second_innings['player_dismissed'].astype('int')
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\2397989033.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['wickets_remaining'] = 10-wickets
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#         extras_type is_wicket player_dismissed dismissal_kind  fielder  \
# 124             NaN         0                1            NaN      NaN
# 125           wides         0                1            NaN      NaN
# 126             NaN         0                1            NaN      NaN
# 127             NaN         0                1            NaN      NaN
# 128             NaN         0                1            NaN      NaN
# ...             ...       ...              ...            ...      ...
# 230277          NaN         0                1            NaN      NaN
# 230278          NaN         0                1            NaN      NaN
# 230279          NaN         0                1            NaN      NaN
# 230280          NaN         0                1            NaN      NaN
# 230281          NaN         0                1            NaN      NaN
#
#         current_score  current_Score runs_left  balls_left  wickets_remaining
# 124                 1              1       222         125                  9
# 125                 2              2       221         124                  8
# 126                 2              2       221         123                  7
# 127                 3              3       220         122                  6
# 128                 4              4       219         121                  5
# ...               ...            ...       ...         ...                ...
# 230277            110            110         4          67                -53
# 230278            111            111         3          66                -54
# 230279            112            112         2          65                -55
# 230280            113            113         1          64                -56
# 230281            114            114         0          63                -57
#
# [111082 rows x 27 columns]

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1691903609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\1691903609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#         player_dismissed dismissal_kind fielder current_score  current_Score  \
# 124                    1            NaN     NaN             1              1
# 125                    1            NaN     NaN             2              2
# 126                    1            NaN     NaN             2              2
# 127                    1            NaN     NaN             3              3
# 128                    1            NaN     NaN             4              4
# ...                  ...            ...     ...           ...            ...
# 230277                 1            NaN     NaN           110            110
# 230278                 1            NaN     NaN           111            111
# 230279                 1            NaN     NaN           112            112
# 230280                 1            NaN     NaN           113            113
# 230281                 1            NaN     NaN           114            114
#
#         runs_left  balls_left wickets_remaining    crr    rrr
# 124           222         125                 9  -1.20  10.66
# 125           221         124                 8  -3.00  10.69
# 126           221         123                 7  -4.00  10.78
# 127           220         122                 6  -9.00  10.82
# 128           219         121                 5 -24.00  10.86
# ...           ...         ...               ...    ...    ...
# 230277          4          67               -53  12.45   0.36
# 230278          3          66               -54  12.33   0.27
# 230279          2          65               -55  12.22   0.18
# 230280          1          64               -56  12.11   0.09
# 230281          0          63               -57  12.00   0.00
#
# [111082 rows x 29 columns]

# %%
def winning_team(team):
    return 1 if team['batting_team'] == team['winner'] else 0

# %%
second_innings['results'] = second_innings.apply(winning_team,axis=1)
second_innings
# Out:
# C:\Users\Aravind\AppData\Local\Temp\ipykernel_39068\3063299583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['results'] = second_innings.apply(winning_team,axis=1)
#         match_id       city                 winner  total_runs_x  \
# 124       335982  Bangalore  Kolkata Knight Riders           223
# 125       335982  Bangalore  Kolkata Knight Riders           223
# 126       335982  Bangalore  Kolkata Knight Riders           223
# 127       335982  Bangalore  Kolkata Knight Riders           223
# 128       335982  Bangalore  Kolkata Knight Riders           223
# ...          ...        ...                    ...           ...
# 230277   1426312    Chennai  Kolkata Knight Riders           114
# 230278   1426312    Chennai  Kolkata Knight Riders           114
# 230279   1426312    Chennai  Kolkata Knight Riders           114
# 230280   1426312    Chennai  Kolkata Knight Riders           114
# 230281   1426312    Chennai  Kolkata Knight Riders           114
#
#                               team1                  team2  inning  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 125     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 127     Royal Challengers Bangalore  Kolkata Knight Riders       2
# 128     Royal Challengers Bangalore  Kolkata Knight Riders       2
# ...                             ...                    ...     ...
# 230277          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230278          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230279          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230280          Sunrisers Hyderabad  Kolkata Knight Riders       2
# 230281          Sunrisers Hyderabad  Kolkata Knight Riders       2
#
#                        batting_team           bowling_team  over  ...  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0  ...
# ...                             ...                    ...   ...  ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad     9  ...
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    10  ...
#
#         dismissal_kind fielder current_score current_Score  runs_left  \
# 124                NaN     NaN             1             1        222
# 125                NaN     NaN             2             2        221
# 126                NaN     NaN             2             2        221
# 127                NaN     NaN             3             3        220
# 128                NaN     NaN             4             4        219
# ...                ...     ...           ...           ...        ...
# 230277             NaN     NaN           110           110          4
# 230278             NaN     NaN           111           111          3
# 230279             NaN     NaN           112           112          2
# 230280             NaN     NaN           113           113          1
# 230281             NaN     NaN           114           114          0
#
#         balls_left  wickets_remaining    crr    rrr  results
# 124            125                  9  -1.20  10.66        0
# 125            124                  8  -3.00  10.69        0
# 126            123                  7  -4.00  10.78        0
# 127            122                  6  -9.00  10.82        0
# 128            121                  5 -24.00  10.86        0
# ...            ...                ...    ...    ...      ...
# 230277          67                -53  12.45   0.36        1
# 230278          66                -54  12.33   0.27        1
# 230279          65                -55  12.22   0.18        1
# 230280          64                -56  12.11   0.09        1
# 230281          63                -57  12.00   0.00        1
#
# [111082 rows x 30 columns]

# %%
required_data = second_innings[['batting_team','bowling_team','city','runs_left','balls_left','wickets_remaining','total_runs_x','crr','rrr','results']]
required_data
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 230277        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230278        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230279        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230280        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 230281        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_remaining  total_runs_x    crr    rrr  \
# 124           222         125                  9           223  -1.20  10.66
# 125           221         124                  8           223  -3.00  10.69
# 126           221         123                  7           223  -4.00  10.78
# 127           220         122                  6           223  -9.00  10.82
# 128           219         121                  5           223 -24.00  10.86
# ...           ...         ...                ...           ...    ...    ...
# 230277          4          67                -53           114  12.45   0.36
# 230278          3          66                -54           114  12.33   0.27
# 230279          2          65                -55           114  12.22   0.18
# 230280          1          64                -56           114  12.11   0.09
# 230281          0          63                -57           114  12.00   0.00
#
#         results
# 124           0
# 125           0
# 126           0
# 127           0
# 128           0
# ...         ...
# 230277        1
# 230278        1
# 230279        1
# 230280        1
# 230281        1
#
# [111082 rows x 10 columns]

# %%
required_data = required_data.replace([np.inf, -np.inf], np.nan)
required_data = required_data.dropna()

# %%
required_data = required_data[required_data['crr'] >= 0]

# %%
columns_to_check = ['runs_left', 'balls_left', 'wickets_remaining', 'total_runs_x', 'crr', 'rrr', 'results']

required_data = required_data[~(required_data[columns_to_check] < 0).any(axis=1)]

# %%
required_data.head()
# Out:
#                     batting_team           bowling_team        city  \
# 130  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 131  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 132  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 133  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 355                 Punjab Kings           Punjab Kings  Chandigarh
#
#      runs_left  balls_left  wickets_remaining  total_runs_x   crr    rrr  \
# 130        219         119                  3           223  24.0  11.04
# 131        219         119                  2           223  24.0  11.04
# 132        219         118                  1           223  12.0  11.14
# 133        215         117                  0           223  16.0  11.03
# 355        231         119                  3           241  60.0  11.65
#
#      results
# 130        0
# 131        0
# 132        0
# 133        0
# 355        0

# %%
numeric = required_data[['runs_left', 'balls_left', 'wickets_remaining', 'total_runs_x', 'crr', 'rrr', 'results']]
has_infinite_values = np.any(np.isinf(numeric))

# Check for negative values in the entire DataFrame
has_negative_values = (numeric < 0).any().any()

# Check for null values in the entire DataFrame
has_null_values = numeric.isnull().any().any()

# Display the results
print(f"Has Infinite Values: {has_infinite_values}")
print(f"Has Negative Values: {has_negative_values}")
print(f"Has Null Values: {has_null_values}")
# Out:
# Has Infinite Values: False
# Has Negative Values: False
# Has Null Values: False

# %%
required_data.to_csv("dataset.csv", index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
x = required_data.iloc[:, :-1]
y = required_data.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train.head()
# Out:
#                        batting_team          bowling_team       city  \
# 28708   Royal Challengers Bangalore          Punjab Kings  Bangalore
# 5599               Rajasthan Royals   Chennai Super Kings     Jaipur
# 185266  Royal Challengers Bangalore        Mumbai Indians       Pune
# 178980  Royal Challengers Bangalore   Sunrisers Hyderabad  Abu Dhabi
# 199532               Delhi Capitals  Lucknow Super Giants    Lucknow
#
#         runs_left  balls_left  wickets_remaining  total_runs_x   crr   rrr
# 28708         204         125                  9           204  -0.0  9.79
# 5599          110         125                  9           110  -0.0  5.28
# 185266        150         119                  3           152  12.0  7.56
# 178980        132         117                  1           142  20.0  6.77
# 199532        186         119                  2           194  48.0  9.38

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Corrected code using `sparse_output=False`
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# c:\Users\Aravind\anaconda3\envs\myenv\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7313182199832073

# %%
pipe.predict_proba(x_test)[0]
# Out:
# array([0.92890067, 0.07109933])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
from sklearn.ensemble import RandomForestClassifier

ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

ra_pipe.fit(x_train,y_train)

ra_y_pred = ra_pipe.predict(x_test)

accuracy_score(y_test,ra_y_pred)
# Out:
# 0.9319899244332494

# %%
import pickle
pickle.dump(ra_pipe,open('ra_pipe.pkl','wb'))

# %%
required_data.head()
# Out:
#                     batting_team           bowling_team        city  \
# 130  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 131  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 132  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 133  Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 355                 Punjab Kings           Punjab Kings  Chandigarh
#
#      runs_left  balls_left  wickets_remaining  total_runs_x   crr    rrr  \
# 130        219         119                  3           223  24.0  11.04
# 131        219         119                  2           223  24.0  11.04
# 132        219         118                  1           223  12.0  11.14
# 133        215         117                  0           223  16.0  11.03
# 355        231         119                  3           241  60.0  11.65
#
#      results
# 130        0
# 131        0
# 132        0
# 133        0
# 355        0
